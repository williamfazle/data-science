# %% [markdown]
# <a href="https://www.kaggle.com/code/williamfazle/data-science?scriptVersionId=282275996" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
print("Data Science")
# Out:
# Data Science

# %%
print("Data Science")
# Out:
# Data Science
